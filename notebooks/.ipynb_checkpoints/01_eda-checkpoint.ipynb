# %%
import os
import urllib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "./../data/raw/"

# %%
train_features= pd.read_csv(path+"train_features.csv")
train_targets_scored = pd.read_csv(path+"train_drug.csv")

# %%
train_features.head()
# Out:
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764
# 3  id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288
# 4  id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919
#
#       g-4     g-5  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.1944 -1.0120  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  1.0190  0.5207  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0323  1.2390  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  4.0620 -0.8095  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  1.4180 -0.8244  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# 1  0.1522  0.1241  0.6077  0.7371
# 2 -0.6417 -0.2187 -1.4080  0.6931
# 3 -1.6210 -0.8784 -0.3876 -0.8154
# 4  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 876 columns]

# %%
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 876 entries, sig_id to c-99
# dtypes: float64(872), int64(1), object(3)
# memory usage: 159.2+ MB

# %% [markdown]
# #### This splitting method would work as long as your dataset is not updated (thereby changing len(data) and the permutation)
# Better to use hashing for a general case with dataset that can be updated. Fine for the scope of this project.

# %%
np.random.seed(42)

# %%
def split_train_set(data,test_ratio):
    perm = np.random.permutation(len(data))
    size = int(len(train_features_df)*test_ratio)
    train_indices = perm[size:]
    test_indices = perm[:size]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
train_data,test_data = split_train_set(train_features,0.2)

# %%
train_targets_scored.shape
# Out:
# (23814, 2)

# %%
train_features.shape
# Out:
# (23814, 876)
